# %% [markdown]
# <a href="https://colab.research.google.com/github/trentbrivers/FinanceNLP/blob/main/finperiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/FinGPT/fingpt-sentiment-train/data/train-00000-of-00001-dabab110260ac909.parquet")

# %%
df['output'].unique()
# Out:
# array(['neutral', 'moderately negative', 'positive', 'mildly positive',
#        'negative', 'moderately positive', 'mildly negative',
#        'strong positive', 'strong negative'], dtype=object)

# %% [markdown]
# What we can see here is that 9 labels are used in this dataset. Something will need to be done about that. My next step is to investigate the difference between the "mild" and "moderate" designations and decide whether they should be condensed into neutral or positive/negative labels.

# %%
df.shape
# Out:
# (76772, 3)

# %%
df[(df['output'] == 'mildly negative')]
# Out:
#                                                    input           output  \
# 63     Alphabet's Q2 earnings were mixed. With the co...  mildly negative
# 82     The economy has been facing severe headwinds, ...  mildly negative
# 130    The formerly high-flying market darling ran in...  mildly negative
# 202    Denmark is effectively banning Google's servic...  mildly negative
# 238    Some investors are understandably demoralized ...  mildly negative
# ...                                                  ...              ...
# 76724  Gene Munster, Loup Ventures managing partner, ...  mildly negative
# 76737  CNBC's Kristina Partsinevelos joins 'Squawk Bo...  mildly negative
# 76746  Little is known for sure about a secretive App...  mildly negative
# 76757  Netflix Inc. executives on Tuesday detailed th...  mildly negative
# 76768  NEW YORK — A fire broke out late Wednesday at ...  mildly negative
#
#                                              instruction
# ...

# %%
df[(df['input'].str.contains("Orange clients"))]
# Out:
#                                                    input   output  \
# 1831   An estimated 30 pct of mobile calls are made f...  neutral
# 9284   An estimated 30 pct of mobile calls are made f...  neutral
# 32204  An estimated 30 pct of mobile calls are made f...  neutral
# 53395  An estimated 30 pct of mobile calls are made f...  neutral
# 57587  An estimated 30 pct of mobile calls are made f...  neutral
# 64999  An estimated 30 pct of mobile calls are made f...  neutral
#
#                                              instruction
# 1831   What is the sentiment of this news? Please cho...
# 9284   What is the sentiment of this news? Please cho...
# 32204  What is the sentiment of this news? Please cho...
# 53395  What is the sentiment of this news? Please cho...
# 57587  What is the sentiment of this news? Please cho...
# 64999  What is the sentiment of this news? Please cho...

# %% [markdown]
# The code cell above was meant to demonstrate two things: firstly, that duplicates exist within the dataset; secondly, that this dataset overlaps with the Financial Phrasebank dataset, which contains the same sentence.

# %%
df_two = df[['input','output']].drop_duplicates()
print(df_two.shape)
df_two.head(10)
# Out:
# (30235, 2)
#                                                input               output
# 0  Teollisuuden Voima Oyj , the Finnish utility k...              neutral
# 1  Sanofi poaches AstraZeneca scientist as new re...              neutral
# 2  Starbucks says the workers violated safety pol...  moderately negative
# 3                      $brcm raises revenue forecast             positive
# 4  Google parent Alphabet Inc. reported revenue a...  moderately negative
# 5  The Finnish company Stockmann has signed the c...              neutral
# 6  Bernie Madoff, the former Wall Street investme...              neutral
# 7        Wall Street's 7 Highest-Rated Stocks to Buy              neutral
# 8  Here we highlight some top-ranked technology E...      mildly positive
# 9               Financial terms were not disclosed .              neutral

# %%
df_two.groupby('output').count()
# Out:
#                      input
# output
# mildly negative       2108
# mildly positive       2548
# moderately negative   2972
# moderately positive   6163
# negative              2169
# neutral              10362
# positive              3484
# strong negative        218
# strong positive        211
